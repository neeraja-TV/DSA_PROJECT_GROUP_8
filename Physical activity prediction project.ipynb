# %%
#EDA Packages
import pandas as pd
import numpy as np

# %%
# Plotting Packages
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ML Packages
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#load the dataset
df=pd.read_csv('/content/drive/MyDrive/sampled_dataset.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0            activityID  heart_rate  hand temperature (°C)  \
# 0     1245151     descending stairs       116.0                32.6875
# 1      698562  transient activities       117.0                30.6875
# 2     1000735     descending stairs       145.0                32.1250
# 3       51545               sitting        93.0                32.6250
# 4       71289              standing       103.0                33.1250
# 5     2195558              standing        71.0                32.5000
# 6     1022930  transient activities       136.0                31.4375
# 7      924879               ironing        85.0                32.6875
# 8     1489501              standing        91.0                35.2500
# 9     1340879        Nordic walking       116.0                29.7500
#
#    hand acceleration X ±16g  hand acceleration Y ±16g  \
# 0                  -7.33257                   5.25923
# 1                   1.84982                   9.75122
# 2                  -4.55761                  -4.27370
# 3                  -7.91338                   4.09584
# 4                  -7.69006                   5.06814
# 5                  -5.41973                   8.45011
# 6                 -11.88720                   3.33944
# 7                  -2.94632                   6.92175
# 8                  -8.82236                   3.18362
# 9                  -5.40830                   7.66743
#
#    hand acceleration Z ±16g  hand gyroscope X  hand gyroscope Y  \
# 0                  3.183940         -0.925192          0.560706
# 1                  0.188855         -0.029437         -0.146707
# 2                  4.566240          1.367570         -0.215928
# 3                  4.102860         -0.007404          0.014535
# 4                  2.717380          0.142284         -0.083325
# 5                  1.046540         -0.329486         -0.021005
# 6                  5.123540         -1.048260         -0.778553
# 7                  6.246050          0.496330         -1.018600
# 8                  3.130140         -1.453440          0.615182
# 9                  2.627330          0.555239         -0.349281
#
#    hand gyroscope Z  ...  ankle acceleration X ±16g  \
# 0          1.067460  ...                    9.90579
# 1          0.023528  ...                    9.61159
# 2          0.016142  ...                   14.30240
# 3         -0.026129  ...                    9.11480
# 4         -0.001429  ...                    9.61089
# 5          0.012804  ...                    9.75657
# 6          1.311740  ...                    6.81100
# 7         -0.836692  ...                    9.53600
# 8          1.196020  ...                    9.79151
# 9          0.666363  ...                   22.17480
#
#    ankle acceleration Y ±16g  ankle acceleration Z ±16g  ankle gyroscope X  \
# 0                   1.313200                  -1.196200          -0.002472
# 1                  -1.907980                  -1.719480           0.007796
# 2                   3.394320                   5.627740          -3.233990
# 3                   0.998793                  -3.942220          -0.003058
# 4                  -2.260700                  -0.366664          -0.025595
# 5                   0.145877                  -2.270990           0.039430
# 6                   5.664510                  -1.640840           1.111290
# 7                  -0.983964                  -3.230980           0.033943
# 8                  -0.119819                  -2.307580           0.264440
# 9                  11.612600                  -7.192860           2.172640
#
#    ankle gyroscope Y  ankle gyroscope Z  ankle magnetometer X  \
# 0           0.685765          -0.650120            -70.820400
# 1          -0.009811           0.019263            -54.016500
# 2           0.015305           6.615370            -41.720600
# 3          -0.052865          -0.013466            -85.337800
# 4           0.010960           0.025672           -109.734000
# 5          -0.032153           0.012047             -0.257292
# 6          -1.387130          -2.203510            -23.469900
# 7           0.090504          -0.008873            -26.816000
# 8          -0.291589          -0.013426             -2.254130
# 9          -0.456929           6.049330            -39.699900
#
#    ankle magnetometer Y  ankle magnetometer Z  PeopleId
# 0               7.96099              25.82870         4
# 1              12.79440               5.84812         2
# 2             -11.26740              15.64080         3
# 3              38.25840              16.03060         1
# 4             -31.58710              23.40700         1
# 5              -6.03105              10.91710         7
# 6              29.35710              15.18210         3
# 7              19.95370              42.95940         3
# 8              -7.40395              35.44860         5
# 9              11.18730              30.89860         4
#
# [10 rows x 34 columns]

# %%
dataset=df.drop(columns=['Unnamed: 0'])

# %%
dataset.head(5)
# Out:
#              activityID  heart_rate  hand temperature (°C)  \
# 0     descending stairs       116.0                32.6875
# 1  transient activities       117.0                30.6875
# 2     descending stairs       145.0                32.1250
# 3               sitting        93.0                32.6250
# 4              standing       103.0                33.1250
#
#    hand acceleration X ±16g  hand acceleration Y ±16g  \
# 0                  -7.33257                   5.25923
# 1                   1.84982                   9.75122
# 2                  -4.55761                  -4.27370
# 3                  -7.91338                   4.09584
# 4                  -7.69006                   5.06814
#
#    hand acceleration Z ±16g  hand gyroscope X  hand gyroscope Y  \
# 0                  3.183940         -0.925192          0.560706
# 1                  0.188855         -0.029437         -0.146707
# 2                  4.566240          1.367570         -0.215928
# 3                  4.102860         -0.007404          0.014535
# 4                  2.717380          0.142284         -0.083325
#
#    hand gyroscope Z  hand magnetometer X  ...  ankle acceleration X ±16g  \
# 0          1.067460             30.60340  ...                    9.90579
# 1          0.023528            -10.64160  ...                    9.61159
# 2          0.016142             29.62470  ...                   14.30240
# 3         -0.026129             -2.09573  ...                    9.11480
# 4         -0.001429             56.44470  ...                    9.61089
#
#    ankle acceleration Y ±16g  ankle acceleration Z ±16g  ankle gyroscope X  \
# 0                   1.313200                  -1.196200          -0.002472
# 1                  -1.907980                  -1.719480           0.007796
# 2                   3.394320                   5.627740          -3.233990
# 3                   0.998793                  -3.942220          -0.003058
# 4                  -2.260700                  -0.366664          -0.025595
#
#    ankle gyroscope Y  ankle gyroscope Z  ankle magnetometer X  \
# 0           0.685765          -0.650120              -70.8204
# 1          -0.009811           0.019263              -54.0165
# 2           0.015305           6.615370              -41.7206
# 3          -0.052865          -0.013466              -85.3378
# 4           0.010960           0.025672             -109.7340
#
#    ankle magnetometer Y  ankle magnetometer Z  PeopleId
# 0               7.96099              25.82870         4
# 1              12.79440               5.84812         2
# 2             -11.26740              15.64080         3
# 3              38.25840              16.03060         1
# 4             -31.58710              23.40700         1
#
# [5 rows x 33 columns]

# %%
print ('Shape of the given dataset is {}.Contains {} rows and {} columns '.format(dataset.shape,dataset.shape[0],dataset.shape[1]))
# Out:
# Shape of the given dataset is (358007, 33).Contains 358007 rows and 33 columns

# %% [markdown]
# # Feature Names and its Datatypes

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358007 entries, 0 to 358006
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   activityID                 358007 non-null  object
#  1   heart_rate                 357998 non-null  float64
#  2   hand temperature (°C)      358007 non-null  float64
#  3   hand acceleration X ±16g   358007 non-null  float64
#  4   hand acceleration Y ±16g   358007 non-null  float64
#  5   hand acceleration Z ±16g   358007 non-null  float64
#  6   hand gyroscope X           358007 non-null  float64
#  7   hand gyroscope Y           358007 non-null  float64
#  8   hand gyroscope Z           358007 non-null  float64
#  9   hand magnetometer X        358007 non-null  float64
#  10  hand magnetometer Y        358007 non-null  float64
#  11  hand magnetometer Z        358007 non-null  float64
#  12  chest temperature (°C)     358007 non-null  float64
#  13  chest acceleration X ±16g  358007 non-null  float64
#  14  chest acceleration Y ±16g  358007 non-null  float64
#  15  chest acceleration Z ±16g  358007 non-null  float64
#  16  chest gyroscope X          358007 non-null  float64
#  17  chest gyroscope Y          358007 non-null  float64
#  18  chest gyroscope Z          358007 non-null  float64
#  19  chest magnetometer X       358007 non-null  float64
#  20  chest magnetometer Y       358007 non-null  float64
#  21  chest magnetometer Z       358007 non-null  float64
#  22  ankle temperature (°C)     358007 non-null  float64
#  23  ankle acceleration X ±16g  358007 non-null  float64
#  24  ankle acceleration Y ±16g  358007 non-null  float64
#  25  ankle acceleration Z ±16g  358007 non-null  float64
#  26  ankle gyroscope X          358007 non-null  float64
#  27  ankle gyroscope Y          358007 non-null  float64
#  28  ankle gyroscope Z          358007 non-null  float64
#  29  ankle magnetometer X       358007 non-null  float64
#  30  ankle magnetometer Y       358007 non-null  float64
#  31  ankle magnetometer Z       358007 non-null  float64
#  32  PeopleId                   358007 non-null  int64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 90.1+ MB

# %% [markdown]
# # Data Spliting
# #Select and separately store Numerical and Categorical features in different variables.

# %%
##Selecting numerical features
numerical_data = dataset.select_dtypes(include='number')
#append the features of numerical_data to list
numerical_features=numerical_data.columns.tolist()

print(f'There are {len(numerical_features)} numerical features:', '\n')
print(numerical_features)
# Out:
# There are 32 numerical features:
#
# ['heart_rate', 'hand temperature (°C)', 'hand acceleration X ±16g', 'hand acceleration Y ±16g', 'hand acceleration Z ±16g', 'hand gyroscope X', 'hand gyroscope Y', 'hand gyroscope Z', 'hand magnetometer X', 'hand magnetometer Y', 'hand magnetometer Z', 'chest temperature (°C)', 'chest acceleration X ±16g', 'chest acceleration Y ±16g', 'chest acceleration Z ±16g', 'chest gyroscope X', 'chest gyroscope Y', 'chest gyroscope Z', 'chest magnetometer X', 'chest magnetometer Y', 'chest magnetometer Z', 'ankle temperature (°C)', 'ankle acceleration X ±16g', 'ankle acceleration Y ±16g', 'ankle acceleration Z ±16g', 'ankle gyroscope X', 'ankle gyroscope Y', 'ankle gyroscope Z', 'ankle magnetometer X', 'ankle magnetometer Y', 'ankle magnetometer Z', 'PeopleId']

# %%
#Selecting categoricalfeatures
categorical_data=dataset.select_dtypes(include= 'object')
#append the features of categorical_data to list
categorical_features=categorical_data.columns.tolist()

print(f'There are {len(categorical_features)} categorical features:', '\n')
print(categorical_features)
# Out:
# There are 1 categorical features:
#
# ['activityID']

# %% [markdown]
# # Descriptive Analysis
# In descriptive Analysis we analysis each variable separately to get inference about the feature.

# %%
numerical_data.describe().T
# Out:
#                               count        mean        std        min  \
# heart_rate                 357998.0  109.798084  25.858938   57.00000
# hand temperature (°C)      358007.0   32.672485   1.800673   27.43750
# hand acceleration X ±16g   358007.0   -4.972517   5.994604  -87.38930
# hand acceleration Y ±16g   358007.0    3.565986   6.228332  -70.29120
# hand acceleration Z ±16g   358007.0    3.184533   3.810917  -61.45220
# hand gyroscope X           358007.0   -0.005401   1.303069  -27.80440
# hand gyroscope Y           358007.0    0.030632   0.886216  -22.21270
# hand gyroscope Z           358007.0   -0.006388   1.455918  -16.69970
# hand magnetometer X        358007.0   21.230708  24.002555 -101.37300
# hand magnetometer Y        358007.0  -14.308053  24.095573 -200.04300
# hand magnetometer Z        358007.0  -21.650625  20.533460 -495.60300
# chest temperature (°C)     358007.0   36.163453   1.572624   30.93750
# chest acceleration X ±16g  358007.0    0.372849   1.610593  -27.92210
# chest acceleration Y ±16g  358007.0    8.520859   4.216272  -31.18120
# chest acceleration Z ±16g  358007.0   -1.515165   4.171651  -53.40190
# chest gyroscope X          358007.0    0.004345   0.398007  -10.15630
# chest gyroscope Y          358007.0    0.008042   0.537788   -6.26193
# chest gyroscope Z          358007.0   -0.019785   0.292517   -7.44090
# chest magnetometer X       358007.0    3.564343  16.443921  -74.40450
# chest magnetometer Y       358007.0  -31.869596  16.098137 -122.48000
# chest magnetometer Z       358007.0    5.503369  19.887562  -66.26160
# ankle temperature (°C)     358007.0   33.691978   1.180459   29.12500
# ankle acceleration X ±16g  358007.0    9.552511   5.627813 -103.20500
# ankle acceleration Y ±16g  358007.0   -0.132186   6.809747 -155.35600
# ankle acceleration Z ±16g  358007.0   -2.452280   3.533576 -134.68400
# ankle gyroscope X          358007.0    0.005754   1.072599  -13.38560
# ankle gyroscope Y          358007.0   -0.034833   0.596242   -8.42390
# ankle gyroscope Z          358007.0    0.005733   1.845338  -13.26960
# ankle magnetometer X       358007.0  -32.723164  18.906569 -172.61600
# ankle magnetometer Y       358007.0    1.621163  21.594782 -136.00300
# ankle magnetometer Z       358007.0   16.865856  20.343376  -95.29860
# PeopleId                   358007.0    4.491225   2.359242    1.00000
#
#                                  25%         50%         75%        max
# heart_rate                 90.000000  108.000000  125.000000  202.00000
# hand temperature (°C)      31.437500   33.125000   34.000000   35.50000
# hand acceleration X ±16g   -9.034770   -5.791870   -0.779855   46.74180
# hand acceleration Y ±16g    1.289225    3.568520    6.598675  147.31300
# hand acceleration Z ±16g    0.980801    2.969950    6.005750   67.00950
# hand gyroscope X           -0.349345   -0.006426    0.301476   21.49750
# hand gyroscope Y           -0.197638    0.006098    0.236019   16.98350
# hand gyroscope Z           -0.304771   -0.005185    0.296644   14.21840
# hand magnetometer X         5.313130   24.235500   39.255450  145.11900
# hand magnetometer Y       -29.531550  -16.426400    1.745900  117.83200
# hand magnetometer Z       -35.197850  -21.494200   -8.442135  175.76600
# chest temperature (°C)     35.187500   36.500000   37.500000   38.56250
# chest acceleration X ±16g  -0.421532    0.445615    1.152510   27.52230
# chest acceleration Y ±16g   7.315310    9.393750    9.802190  141.51200
# chest acceleration Z ±16g  -3.875490   -1.276870    0.399706   36.71640
# chest gyroscope X          -0.092038    0.003098    0.098916   13.22100
# chest gyroscope Y          -0.128283   -0.000093    0.147255    5.61486
# chest gyroscope Z          -0.111107   -0.015938    0.072998    3.42798
# chest magnetometer X       -6.803245    2.241480   13.458450   67.60490
# chest magnetometer Y      -40.221100  -33.511300  -24.966650   42.43800
# chest magnetometer Z       -8.333575    5.072060   19.197800   95.10180
# ankle temperature (°C)     33.000000   34.000000   34.562500   35.43750
# ankle acceleration X ±16g   9.033960    9.575770   10.012450  157.23200
# ankle acceleration Y ±16g  -1.759455   -0.271861    1.255610  155.94800
# ankle acceleration Z ±16g  -3.635570   -2.350760   -1.055020  158.87200
# ankle gyroscope X          -0.156519    0.004052    0.093749   16.44270
# ankle gyroscope Y          -0.082808   -0.004235    0.083326   13.16350
# ankle gyroscope Z          -0.311319   -0.002476    0.063536   13.90460
# ankle magnetometer X      -42.912300  -33.886400  -19.065500   97.52550
# ankle magnetometer Y      -11.381200    1.392580   17.333050  123.30600
# ankle magnetometer Z        3.232825   18.101700   30.878650  138.16300
# PeopleId                    2.000000    5.000000    7.000000    8.00000

# %%
#Summary satistics of Categorical features
categorical_data.describe(include='object').T
# Out:
#              count unique                   top    freq
# activityID  358007     13  transient activities  116265

# %%
#Variance of each numerical features
numerical_data.var()
# Out:
# heart_rate                   668.684650
# hand temperature (°C)          3.242424
# hand acceleration X ±16g      35.935281
# hand acceleration Y ±16g      38.792114
# hand acceleration Z ±16g      14.523087
# hand gyroscope X               1.697988
# hand gyroscope Y               0.785379
# hand gyroscope Z               2.119698
# hand magnetometer X          576.122655
# hand magnetometer Y          580.596642
# hand magnetometer Z          421.622963
# chest temperature (°C)         2.473145
# chest acceleration X ±16g      2.594010
# chest acceleration Y ±16g     17.776950
# chest acceleration Z ±16g     17.402673
# chest gyroscope X              0.158410
# chest gyroscope Y              0.289216
# chest gyroscope Z              0.085566
# chest magnetometer X         270.402553
# chest magnetometer Y         259.150015
# chest magnetometer Z         395.515133
# ankle temperature (°C)         1.393484
# ankle acceleration X ±16g     31.672279
# ankle acceleration Y ±16g     46.372655
# ankle acceleration Z ±16g     12.486158
# ankle gyroscope X              1.150469
# ankle gyroscope Y              0.355504
# ankle gyroscope Z              3.405272
# ankle magnetometer X         357.458360
# ankle magnetometer Y         466.334612
# ankle magnetometer Z         413.852931
# PeopleId                       5.566025
# dtype: float64

# %%
#Skew in numerical features
numerical_data.skew()
# Out:
# heart_rate                   0.600281
# hand temperature (°C)       -0.811346
# hand acceleration X ±16g    -0.308143
# hand acceleration Y ±16g     1.844614
# hand acceleration Z ±16g    -0.544136
# hand gyroscope X             0.057980
# hand gyroscope Y             0.537558
# hand gyroscope Z            -0.224864
# hand magnetometer X         -0.476491
# hand magnetometer Y         -0.089258
# hand magnetometer Z         -0.040068
# chest temperature (°C)      -0.684210
# chest acceleration X ±16g    0.180041
# chest acceleration Y ±16g    1.604216
# chest acceleration Z ±16g    0.305503
# chest gyroscope X            2.673222
# chest gyroscope Y           -0.034324
# chest gyroscope Z           -0.092985
# chest magnetometer X         0.215209
# chest magnetometer Y         0.656713
# chest magnetometer Z         0.096158
# ankle temperature (°C)      -0.981662
# ankle acceleration X ±16g    2.650161
# ankle acceleration Y ±16g    0.294082
# ankle acceleration Z ±16g   -0.747904
# ankle gyroscope X            0.177283
# ankle gyroscope Y           -1.026858
# ankle gyroscope Z            0.869862
# ankle magnetometer X        -0.489585
# ankle magnetometer Y        -0.342371
# ankle magnetometer Z        -0.355392
# PeopleId                     0.004195
# dtype: float64

# %% [markdown]
# # Observation
# ## 1.Features such as ankle acceleration X,chest gyroscope X has high positive skew ranges.
# ## 2.And ankle gyroscope Y has high negative skew.
# ## 3.Rest of features shows moderate range of positive and negative skew.

# %% [markdown]
# # Histograms
# To find the distributions and outlier in the each feature

# %%
numerical_data.hist(figsize=(24,24),bins=20)
plt.show()

# %% [markdown]
# # Number Unique values in each feature

# %%
numerical_data.nunique()
# Out:
# heart_rate                     2913
# hand temperature (°C)           145
# hand acceleration X ±16g     289998
# hand acceleration Y ±16g     302895
# hand acceleration Z ±16g     297715
# hand gyroscope X             338441
# hand gyroscope Y             336296
# hand gyroscope Z             335439
# hand magnetometer X          293523
# hand magnetometer Y          295110
# hand magnetometer Z          286799
# chest temperature (°C)          130
# chest acceleration X ±16g    279031
# chest acceleration Y ±16g    222908
# chest acceleration Z ±16g    284045
# chest gyroscope X            333877
# chest gyroscope Y            337455
# chest gyroscope Z            333169
# chest magnetometer X         307026
# chest magnetometer Y         236767
# chest magnetometer Z         295927
# ankle temperature (°C)          126
# ankle acceleration X ±16g    199717
# ankle acceleration Y ±16g    258559
# ankle acceleration Z ±16g    243486
# ankle gyroscope X            332045
# ankle gyroscope Y            337003
# ankle gyroscope Z            338367
# ankle magnetometer X         255302
# ankle magnetometer Y         296596
# ankle magnetometer Z         272510
# PeopleId                          8
# dtype: int64

# %%
#Missing Values
numerical_data.isnull().sum()
# Out:
# heart_rate                   9
# hand temperature (°C)        0
# hand acceleration X ±16g     0
# hand acceleration Y ±16g     0
# hand acceleration Z ±16g     0
# hand gyroscope X             0
# hand gyroscope Y             0
# hand gyroscope Z             0
# hand magnetometer X          0
# hand magnetometer Y          0
# hand magnetometer Z          0
# chest temperature (°C)       0
# chest acceleration X ±16g    0
# chest acceleration Y ±16g    0
# chest acceleration Z ±16g    0
# chest gyroscope X            0
# chest gyroscope Y            0
# chest gyroscope Z            0
# chest magnetometer X         0
# chest magnetometer Y         0
# chest magnetometer Z         0
# ankle temperature (°C)       0
# ankle acceleration X ±16g    0
# ankle acceleration Y ±16g    0
# ankle acceleration Z ±16g    0
# ankle gyroscope X            0
# ankle gyroscope Y            0
# ankle gyroscope Z            0
# ankle magnetometer X         0
# ankle magnetometer Y         0
# ankle magnetometer Z         0
# PeopleId                     0
# dtype: int64

# %% [markdown]
# # Observations
# ## 1.hand temperature (°C), chest temperature (°C),ankle temperature (°C) contains mostly non-unique values but rest of the features show more variations.
# ## 2.heart_rate contains missing values so we need to use of any statistical imputations.
# ## 3. Except PeopleID all other features shows gaussian like distribution

# %% [markdown]
# # Categorical Features
# No of unique values in each categorical feature

# %%
# unique values counts
unique_values=categorical_data.activityID.unique()

unique_values
# Out:
# array(['descending stairs', 'transient activities', 'sitting', 'standing',
#        'ironing', 'Nordic walking', 'lying', 'walking', 'cycling',
#        'running', 'ascending stairs', 'vacuum cleaning', 'rope jumping'],
#       dtype=object)

# %%
unique_counts=categorical_data.nunique()
unique_counts
# Out:
# activityID    13
# dtype: int64

# %%
#Barplot of unique value counts in every categorical features
#through Looping generate bar plots of unqiue value counts in each variable
for col in categorical_features:
    print()
    print(f"\033[1m{col}\033[0m\n") #print column name above the plot
    categorical_data[col].value_counts().sort_index().plot(kind='bar', rot=90, xlabel=col,ylabel='count')
    plt.show()
# Out:
# activityID

# %% [markdown]
# # Observations
# From the barplots of unique values in each categorical features shows how balanced those unique values in that specific feature.

# %% [markdown]
# # Correlation Analysis
# Correlation matrix of whole dataset

# %%
# Generating correlation coefficient between each features
from pandas import set_option
set_option("display.precision",3)
correlation=dataset.corr(method='pearson')
correlation
# Out:
# <ipython-input-23-8c54df4fc671>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=dataset.corr(method='pearson')
#                            heart_rate  hand temperature (°C)  \
# heart_rate                  1.000e+00             -3.724e-01
# hand temperature (°C)      -3.724e-01              1.000e+00
# hand acceleration X ±16g   -1.898e-01              1.301e-02
# hand acceleration Y ±16g    2.758e-02             -4.314e-02
# hand acceleration Z ±16g   -2.097e-01              6.236e-02
# hand gyroscope X            6.051e-03             -1.765e-02
# hand gyroscope Y            4.372e-02             -1.157e-02
# hand gyroscope Z           -3.957e-03              1.819e-03
# hand magnetometer X         2.024e-01             -6.670e-02
# hand magnetometer Y        -8.242e-02             -2.321e-02
# hand magnetometer Z         7.991e-02             -2.684e-02
# chest temperature (°C)     -1.628e-01              7.800e-01
# chest acceleration X ±16g  -2.034e-02              3.399e-02
# chest acceleration Y ±16g   1.397e-01              3.007e-02
# chest acceleration Z ±16g  -3.336e-01              7.955e-02
# chest gyroscope X           3.021e-03              2.353e-03
# chest gyroscope Y           1.586e-02             -6.892e-03
# chest gyroscope Z          -1.321e-02             -2.397e-03
# chest magnetometer X       -1.142e-01             -3.920e-02
# chest magnetometer Y       -3.547e-01              4.227e-04
# chest magnetometer Z        3.458e-01             -1.615e-01
# ankle temperature (°C)     -7.909e-02              5.227e-01
# ankle acceleration X ±16g   2.314e-01             -4.264e-02
# ankle acceleration Y ±16g   1.552e-01             -3.464e-02
# ankle acceleration Z ±16g   1.023e-02             -7.538e-02
# ankle gyroscope X          -1.492e-04              1.292e-03
# ankle gyroscope Y          -2.137e-02              2.212e-02
# ankle gyroscope Z           3.404e-03             -1.239e-03
# ankle magnetometer X       -2.655e-01              8.334e-02
# ankle magnetometer Y       -1.637e-01              8.939e-02
# ankle magnetometer Z       -6.676e-02              1.352e-01
# PeopleId                   -1.199e-01              1.724e-01
#
#                            hand acceleration X ±16g  hand acceleration Y ±16g  \
# heart_rate                                   -0.190                 2.758e-02
# hand temperature (°C)                         0.013                -4.314e-02
# hand acceleration X ±16g                      1.000                -2.268e-02
# hand acceleration Y ±16g                     -0.023                 1.000e+00
# hand acceleration Z ±16g                      0.214                -8.640e-02
# hand gyroscope X                              0.017                 1.408e-01
# hand gyroscope Y                             -0.079                 1.025e-04
# hand gyroscope Z                              0.028                 2.408e-02
# hand magnetometer X                          -0.580                -9.108e-02
# hand magnetometer Y                          -0.012                -4.873e-01
# hand magnetometer Z                          -0.158                 1.040e-01
# chest temperature (°C)                       -0.131                -4.595e-02
# chest acceleration X ±16g                    -0.005                 3.883e-02
# chest acceleration Y ±16g                    -0.360                 1.838e-01
# chest acceleration Z ±16g                     0.353                -1.322e-01
# chest gyroscope X                            -0.058                 5.167e-02
# chest gyroscope Y                            -0.041                 6.360e-03
# chest gyroscope Z                             0.065                 3.088e-02
# chest magnetometer X                          0.172                -7.490e-02
# chest magnetometer Y                          0.234                -9.620e-02
# chest magnetometer Z                         -0.259                 5.193e-02
# ankle temperature (°C)                       -0.094                 1.120e-01
# ankle acceleration X ±16g                    -0.249                 4.818e-02
# ankle acceleration Y ±16g                    -0.081                 1.041e-01
# ankle acceleration Z ±16g                     0.018                 2.993e-02
# ankle gyroscope X                             0.034                -9.640e-04
# ankle gyroscope Y                            -0.054                -2.546e-02
# ankle gyroscope Z                             0.084                -3.360e-02
# ankle magnetometer X                          0.045                -7.897e-02
# ankle magnetometer Y                          0.165                -9.734e-02
# ankle magnetometer Z                         -0.041                 3.590e-02
# PeopleId                                     -0.077                -3.567e-01
#
#                            hand acceleration Z ±16g  hand gyroscope X  \
# heart_rate                                   -0.210         6.051e-03
# hand temperature (°C)                         0.062        -1.765e-02
# hand acceleration X ±16g                      0.214         1.702e-02
# hand acceleration Y ±16g                     -0.086         1.408e-01
# hand acceleration Z ±16g                      1.000        -2.208e-02
# hand gyroscope X                             -0.022         1.000e+00
# hand gyroscope Y                             -0.006        -2.008e-01
# hand gyroscope Z                             -0.063        -2.218e-01
# hand magnetometer X                          -0.144         2.705e-03
# hand magnetometer Y                           0.131        -1.179e-02
# hand magnetometer Z                          -0.534         5.270e-03
# chest temperature (°C)                       -0.026        -1.728e-02
# chest acceleration X ±16g                    -0.092        -8.199e-02
# chest acceleration Y ±16g                    -0.072         8.447e-03
# chest acceleration Z ±16g                     0.135         7.494e-03
# chest gyroscope X                            -0.001         3.639e-03
# chest gyroscope Y                            -0.041        -2.464e-01
# chest gyroscope Z                             0.029         1.841e-01
# chest magnetometer X                          0.168        -5.704e-03
# chest magnetometer Y                          0.178        -2.755e-03
# chest magnetometer Z                         -0.122         3.250e-03
# ankle temperature (°C)                       -0.028        -2.810e-03
# ankle acceleration X ±16g                    -0.153         1.753e-02
# ankle acceleration Y ±16g                    -0.047         9.377e-03
# ankle acceleration Z ±16g                     0.014        -1.104e-02
# ankle gyroscope X                             0.013         2.078e-02
# ankle gyroscope Y                            -0.014        -3.453e-02
# ankle gyroscope Z                             0.023         1.313e-01
# ankle magnetometer X                          0.082         1.256e-02
# ankle magnetometer Y                          0.067        -5.594e-02
# ankle magnetometer Z                         -0.042        -3.259e-04
# PeopleId                                      0.032        -2.040e-02
#
#                            hand gyroscope Y  hand gyroscope Z  \
# heart_rate                        4.372e-02        -3.957e-03
# hand temperature (°C)            -1.157e-02         1.819e-03
# hand acceleration X ±16g         -7.885e-02         2.838e-02
# hand acceleration Y ±16g          1.025e-04         2.408e-02
# hand acceleration Z ±16g         -5.588e-03        -6.281e-02
# hand gyroscope X                 -2.008e-01        -2.218e-01
# hand gyroscope Y                  1.000e+00         7.289e-02
# hand gyroscope Z                  7.289e-02         1.000e+00
# hand magnetometer X              -3.809e-02        -8.649e-03
# hand magnetometer Y              -7.876e-03        -2.257e-02
# hand magnetometer Z              -1.344e-03         2.368e-03
# chest temperature (°C)           -1.569e-02         9.130e-04
# chest acceleration X ±16g         5.028e-02         1.735e-01
# chest acceleration Y ±16g         4.269e-02        -5.490e-02
# chest acceleration Z ±16g        -1.801e-02         1.476e-02
# chest gyroscope X                 5.064e-02        -8.423e-02
# chest gyroscope Y                 2.543e-01         3.076e-01
# chest gyroscope Z                -1.449e-01        -1.775e-01
# chest magnetometer X             -6.718e-03        -2.152e-02
# chest magnetometer Y             -2.192e-02         2.103e-03
# chest magnetometer Z              1.071e-03         5.485e-03
# ankle temperature (°C)           -1.244e-02         5.658e-05
# ankle acceleration X ±16g         4.276e-02        -1.753e-02
# ankle acceleration Y ±16g         3.414e-03         4.813e-02
# ankle acceleration Z ±16g        -3.208e-02         3.081e-02
# ankle gyroscope X                 5.215e-02        -3.340e-02
# ankle gyroscope Y                 8.708e-02        -1.753e-02
# ankle gyroscope Z                -1.804e-02        -1.548e-01
# ankle magnetometer X             -8.145e-04        -5.180e-02
# ankle magnetometer Y              1.811e-03         1.137e-01
# ankle magnetometer Z             -1.898e-02         2.803e-02
# PeopleId                          4.828e-03        -2.052e-03
#
#                            hand magnetometer X  hand magnetometer Y  ...  \
# heart_rate                               0.202               -0.082  ...
# hand temperature (°C)                   -0.067               -0.023  ...
# hand acceleration X ±16g                -0.580               -0.012  ...
# hand acceleration Y ±16g                -0.091               -0.487  ...
# hand acceleration Z ±16g                -0.144                0.131  ...
# hand gyroscope X                         0.003               -0.012  ...
# hand gyroscope Y                        -0.038               -0.008  ...
# hand gyroscope Z                        -0.009               -0.023  ...
# hand magnetometer X                      1.000                0.133  ...
# hand magnetometer Y                      0.133                1.000  ...
# hand magnetometer Z                      0.178               -0.118  ...
# chest temperature (°C)                   0.081               -0.020  ...
# chest acceleration X ±16g                0.031                0.018  ...
# chest acceleration Y ±16g                0.086               -0.128  ...
# chest acceleration Z ±16g               -0.229                0.216  ...
# chest gyroscope X                       -0.003               -0.006  ...
# chest gyroscope Y                        0.009                0.021  ...
# chest gyroscope Z                        0.023                0.035  ...
# chest magnetometer X                    -0.060                0.401  ...
# chest magnetometer Y                    -0.126                0.380  ...
# chest magnetometer Z                     0.476               -0.038  ...
# ankle temperature (°C)                   0.015               -0.167  ...
# ankle acceleration X ±16g                0.150               -0.137  ...
# ankle acceleration Y ±16g                0.106               -0.070  ...
# ankle acceleration Z ±16g                0.018               -0.070  ...
# ankle gyroscope X                        0.037                0.062  ...
# ankle gyroscope Y                       -0.072               -0.018  ...
# ankle gyroscope Z                        0.043                0.044  ...
# ankle magnetometer X                    -0.053                0.251  ...
# ankle magnetometer Y                    -0.259                0.106  ...
# ankle magnetometer Z                    -0.125               -0.240  ...
# PeopleId                                 0.115                0.383  ...
#
#                            ankle acceleration X ±16g  \
# heart_rate                                     0.231
# hand temperature (°C)                         -0.043
# hand acceleration X ±16g                      -0.249
# hand acceleration Y ±16g                       0.048
# hand acceleration Z ±16g                      -0.153
# hand gyroscope X                               0.018
# hand gyroscope Y                               0.043
# hand gyroscope Z                              -0.018
# hand magnetometer X                            0.150
# hand magnetometer Y                           -0.137
# hand magnetometer Z                            0.104
# chest temperature (°C)                         0.088
# chest acceleration X ±16g                     -0.047
# chest acceleration Y ±16g                      0.302
# chest acceleration Z ±16g                     -0.271
# chest gyroscope X                             -0.030
# chest gyroscope Y                              0.054
# chest gyroscope Z                             -0.063
# chest magnetometer X                          -0.212
# chest magnetometer Y                          -0.314
# chest magnetometer Z                           0.218
# ankle temperature (°C)                         0.079
# ankle acceleration X ±16g                      1.000
# ankle acceleration Y ±16g                      0.129
# ankle acceleration Z ±16g                      0.057
# ankle gyroscope X                             -0.003
# ankle gyroscope Y                             -0.049
# ankle gyroscope Z                             -0.035
# ankle magnetometer X                          -0.188
# ankle magnetometer Y                          -0.084
# ankle magnetometer Z                           0.106
# PeopleId                                      -0.003
#
#                            ankle acceleration Y ±16g  \
# heart_rate                                     0.155
# hand temperature (°C)                         -0.035
# hand acceleration X ±16g                      -0.081
# hand acceleration Y ±16g                       0.104
# hand acceleration Z ±16g                      -0.047
# hand gyroscope X                               0.009
# hand gyroscope Y                               0.003
# hand gyroscope Z                               0.048
# hand magnetometer X                            0.106
# hand magnetometer Y                           -0.070
# hand magnetometer Z                            0.069
# chest temperature (°C)                         0.043
# chest acceleration X ±16g                      0.035
# chest acceleration Y ±16g                      0.098
# chest acceleration Z ±16g                     -0.195
# chest gyroscope X                              0.032
# chest gyroscope Y                              0.062
# chest gyroscope Z                              0.066
# chest magnetometer X                          -0.128
# chest magnetometer Y                          -0.157
# chest magnetometer Z                           0.154
# ankle temperature (°C)                         0.058
# ankle acceleration X ±16g                      0.129
# ankle acceleration Y ±16g                      1.000
# ankle acceleration Z ±16g                     -0.137
# ankle gyroscope X                              0.143
# ankle gyroscope Y                             -0.054
# ankle gyroscope Z                              0.145
# ankle magnetometer X                          -0.086
# ankle magnetometer Y                          -0.042
# ankle magnetometer Z                           0.074
# PeopleId                                      -0.013
#
#                            ankle acceleration Z ±16g  ankle gyroscope X  \
# heart_rate                                     0.010         -1.492e-04
# hand temperature (°C)                         -0.075          1.292e-03
# hand acceleration X ±16g                       0.018          3.355e-02
# hand acceleration Y ±16g                       0.030         -9.640e-04
# hand acceleration Z ±16g                       0.014          1.254e-02
# hand gyroscope X                              -0.011          2.078e-02
# hand gyroscope Y                              -0.032          5.215e-02
# hand gyroscope Z                               0.031         -3.340e-02
# hand magnetometer X                            0.018          3.663e-02
# hand magnetometer Y                           -0.070          6.170e-02
# hand magnetometer Z                           -0.018          7.790e-03
# chest temperature (°C)                        -0.077         -3.685e-04
# chest acceleration X ±16g                     -0.071          6.794e-02
# chest acceleration Y ±16g                      0.004         -3.358e-02
# chest acceleration Z ±16g                     -0.131          1.469e-02
# chest gyroscope X                             -0.012          1.531e-02
# chest gyroscope Y                             -0.016          1.792e-01
# chest gyroscope Z                              0.010          1.398e-01
# chest magnetometer X                          -0.038          1.366e-04
# chest magnetometer Y                          -0.018          1.898e-03
# chest magnetometer Z                           0.125          3.807e-03
# ankle temperature (°C)                         0.053         -8.613e-03
# ankle acceleration X ±16g                      0.057         -2.647e-03
# ankle acceleration Y ±16g                     -0.137          1.426e-01
# ankle acceleration Z ±16g                      1.000         -8.363e-02
# ankle gyroscope X                             -0.084          1.000e+00
# ankle gyroscope Y                             -0.074         -5.415e-02
# ankle gyroscope Z                             -0.015          3.154e-01
# ankle magnetometer X                          -0.021         -1.795e-02
# ankle magnetometer Y                          -0.036          5.481e-02
# ankle magnetometer Z                          -0.052         -9.772e-03
# PeopleId                                      -0.178          1.323e-02
#
#                            ankle gyroscope Y  ankle gyroscope Z  \
# heart_rate                            -0.021              0.003
# hand temperature (°C)                  0.022             -0.001
# hand acceleration X ±16g              -0.054              0.084
# hand acceleration Y ±16g              -0.025             -0.034
# hand acceleration Z ±16g              -0.014              0.023
# hand gyroscope X                      -0.035              0.131
# hand gyroscope Y                       0.087             -0.018
# hand gyroscope Z                      -0.018             -0.155
# hand magnetometer X                   -0.072              0.043
# hand magnetometer Y                   -0.018              0.044
# hand magnetometer Z                   -0.036              0.009
# chest temperature (°C)                -0.002             -0.002
# chest acceleration X ±16g             -0.035             -0.059
# chest acceleration Y ±16g              0.038             -0.109
# chest acceleration Z ±16g             -0.024              0.071
# chest gyroscope X                     -0.026             -0.022
# chest gyroscope Y                      0.064             -0.070
# chest gyroscope Z                     -0.115              0.257
# chest magnetometer X                   0.009              0.002
# chest magnetometer Y                   0.016             -0.003
# chest magnetometer Z                   0.004              0.002
# ankle temperature (°C)                 0.007              0.004
# ankle acceleration X ±16g             -0.049             -0.035
# ankle acceleration Y ±16g             -0.054              0.145
# ankle acceleration Z ±16g             -0.074             -0.015
# ankle gyroscope X                     -0.054              0.315
# ankle gyroscope Y                      1.000              0.011
# ankle gyroscope Z                      0.011              1.000
# ankle magnetometer X                   0.017             -0.004
# ankle magnetometer Y                  -0.029              0.011
# ankle magnetometer Z                  -0.018             -0.014
# PeopleId                              -0.006             -0.007
#
#                            ankle magnetometer X  ankle magnetometer Y  \
# heart_rate                           -2.655e-01                -0.164
# hand temperature (°C)                 8.334e-02                 0.089
# hand acceleration X ±16g              4.473e-02                 0.165
# hand acceleration Y ±16g             -7.897e-02                -0.097
# hand acceleration Z ±16g              8.193e-02                 0.067
# hand gyroscope X                      1.256e-02                -0.056
# hand gyroscope Y                     -8.145e-04                 0.002
# hand gyroscope Z                     -5.180e-02                 0.114
# hand magnetometer X                  -5.334e-02                -0.259
# hand magnetometer Y                   2.513e-01                 0.106
# hand magnetometer Z                   1.222e-01                -0.163
# chest temperature (°C)                2.692e-02                 0.024
# chest acceleration X ±16g             2.324e-02                 0.022
# chest acceleration Y ±16g            -8.703e-02                -0.121
# chest acceleration Z ±16g             1.908e-01                 0.222
# chest gyroscope X                     6.509e-03                -0.006
# chest gyroscope Y                    -3.783e-02                 0.069
# chest gyroscope Z                     2.795e-02                -0.004
# chest magnetometer X                  1.191e-01                 0.246
# chest magnetometer Y                  5.379e-01                 0.121
# chest magnetometer Z                 -1.230e-01                -0.449
# ankle temperature (°C)               -5.748e-02                -0.046
# ankle acceleration X ±16g            -1.876e-01                -0.084
# ankle acceleration Y ±16g            -8.596e-02                -0.042
# ankle acceleration Z ±16g            -2.149e-02                -0.036
# ankle gyroscope X                    -1.795e-02                 0.055
# ankle gyroscope Y                     1.689e-02                -0.029
# ankle gyroscope Z                    -3.884e-03                 0.011
# ankle magnetometer X                  1.000e+00                 0.031
# ankle magnetometer Y                  3.068e-02                 1.000
# ankle magnetometer Z                 -3.492e-03                 0.030
# PeopleId                              2.101e-01                 0.111
#
#                            ankle magnetometer Z  PeopleId
# heart_rate                           -6.676e-02    -0.120
# hand temperature (°C)                 1.352e-01     0.172
# hand acceleration X ±16g             -4.115e-02    -0.077
# hand acceleration Y ±16g              3.590e-02    -0.357
# hand acceleration Z ±16g             -4.187e-02     0.032
# hand gyroscope X                     -3.259e-04    -0.020
# hand gyroscope Y                     -1.898e-02     0.005
# hand gyroscope Z                      2.803e-02    -0.002
# hand magnetometer X                  -1.253e-01     0.115
# hand magnetometer Y                  -2.400e-01     0.383
# hand magnetometer Z                   2.157e-01     0.010
# chest temperature (°C)                1.241e-01     0.234
# chest acceleration X ±16g             5.097e-02     0.062
# chest acceleration Y ±16g             1.289e-01     0.062
# chest acceleration Z ±16g            -9.466e-02     0.216
# chest gyroscope X                    -2.870e-03    -0.001
# chest gyroscope Y                    -2.182e-03     0.013
# chest gyroscope Z                    -1.632e-02    -0.014
# chest magnetometer X                 -5.289e-01     0.080
# chest magnetometer Y                 -1.883e-01     0.125
# chest magnetometer Z                 -1.428e-01    -0.110
# ankle temperature (°C)                8.608e-02    -0.218
# ankle acceleration X ±16g             1.061e-01    -0.003
# ankle acceleration Y ±16g             7.405e-02    -0.013
# ankle acceleration Z ±16g            -5.176e-02    -0.178
# ankle gyroscope X                    -9.772e-03     0.013
# ankle gyroscope Y                    -1.823e-02    -0.006
# ankle gyroscope Z                    -1.450e-02    -0.007
# ankle magnetometer X                 -3.492e-03     0.210
# ankle magnetometer Y                  3.043e-02     0.111
# ankle magnetometer Z                  1.000e+00     0.050
# PeopleId                              4.997e-02     1.000
#
# [32 rows x 32 columns]

# %%
#Correlation Heatmap plot of whole dataset
# Plot correlation matrix in heatmap
fig, ax = plt.subplots(figsize=(40, 30))
sns.heatmap(dataset.corr(), ax=ax, annot=True)
plt.show()
# Out:
# <ipython-input-24-780a2d70179f>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dataset.corr(), ax=ax, annot=True)

# %% [markdown]
# # Data visualization
# Some other visualizations of features to get more insights
#
# Density plots of numerical features

# %%
numerical_data.plot(kind='density',figsize=(14,14),subplots=True,layout=(16,2),title="Density plot of Numerical features",sharex=False)
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Checking for missing values

# %%
dataset.isnull().sum()
# Out:
# activityID                   0
# heart_rate                   9
# hand temperature (°C)        0
# hand acceleration X ±16g     0
# hand acceleration Y ±16g     0
# hand acceleration Z ±16g     0
# hand gyroscope X             0
# hand gyroscope Y             0
# hand gyroscope Z             0
# hand magnetometer X          0
# hand magnetometer Y          0
# hand magnetometer Z          0
# chest temperature (°C)       0
# chest acceleration X ±16g    0
# chest acceleration Y ±16g    0
# chest acceleration Z ±16g    0
# chest gyroscope X            0
# chest gyroscope Y            0
# chest gyroscope Z            0
# chest magnetometer X         0
# chest magnetometer Y         0
# chest magnetometer Z         0
# ankle temperature (°C)       0
# ankle acceleration X ±16g    0
# ankle acceleration Y ±16g    0
# ankle acceleration Z ±16g    0
# ankle gyroscope X            0
# ankle gyroscope Y            0
# ankle gyroscope Z            0
# ankle magnetometer X         0
# ankle magnetometer Y         0
# ankle magnetometer Z         0
# PeopleId                     0
# dtype: int64

# %% [markdown]
# Initializing the SimpleImputer object with the 'mean' strategy. The 'mean' strategy will replace missing values with the mean of the non-missing values in the "heart_rate" column.

# %%
# Initialize the SimpleImputer with 'mean' strategy
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')

# %%
# Fit and transform the 'heart_rate' column to fill missing values
dataset['heart_rate'] = imputer.fit_transform(dataset[['heart_rate']])

# %%
# Check the number of missing values after imputation
missing_values_after_imputation = dataset['heart_rate'].isnull().sum()
print(f"Number of missing values after imputation: {missing_values_after_imputation}")
# Out:
# Number of missing values after imputation: 0

# %% [markdown]
# # Outlier Detection

# %%
dataset.columns
# Out:
# Index(['activityID', 'heart_rate', 'hand temperature (°C)',
#        'hand acceleration X ±16g', 'hand acceleration Y ±16g',
#        'hand acceleration Z ±16g', 'hand gyroscope X', 'hand gyroscope Y',
#        'hand gyroscope Z', 'hand magnetometer X', 'hand magnetometer Y',
#        'hand magnetometer Z', 'chest temperature (°C)',
#        'chest acceleration X ±16g', 'chest acceleration Y ±16g',
#        'chest acceleration Z ±16g', 'chest gyroscope X', 'chest gyroscope Y',
#        'chest gyroscope Z', 'chest magnetometer X', 'chest magnetometer Y',
#        'chest magnetometer Z', 'ankle temperature (°C)',
#        'ankle acceleration X ±16g', 'ankle acceleration Y ±16g',
#        'ankle acceleration Z ±16g', 'ankle gyroscope X', 'ankle gyroscope Y',
#        'ankle gyroscope Z', 'ankle magnetometer X', 'ankle magnetometer Y',
#        'ankle magnetometer Z', 'PeopleId'],
#       dtype='object')

# %% [markdown]
# # Z - Score Method

# %%
# Define a function to detect outliers using Z-score
def find_outliers_zscore(dataset, threshold=3):
    z_scores = np.abs((dataset - dataset.mean()) / dataset.std())
    return z_scores > threshold

# %%
# Find outliers in all columns (except the 'activityID' and 'PeopleId' columns if they exist)
outliers_all_columns = dataset.drop(columns=['activityID', 'PeopleId']).apply(find_outliers_zscore)

# %%
# Show the rows where any column has an outlier
outliers_rows = outliers_all_columns.any(axis=1)
outliers_detected = dataset[outliers_rows]

# %%
# Get the index of potential outliers
potential_outliers_index = outliers_detected.index

# %%
potential_outliers_index
# Out:
# Int64Index([     2,      4,      9,     11,     18,     21,     25,     27,
#                 29,     31,
#             ...
#             357978, 357984, 357985, 357987, 357988, 357990, 357994, 357997,
#             358002, 358004],
#            dtype='int64', length=80294)

# %%
# Remove the potential outliers from the original DataFrame
df_cleaned = dataset.drop(index=potential_outliers_index)

# %%
df_cleaned
# Out:
#                   activityID  heart_rate  hand temperature (°C)  \
# 0          descending stairs       116.0                 32.688
# 1       transient activities       117.0                 30.688
# 3                    sitting        93.0                 32.625
# 5                   standing        71.0                 32.500
# 6       transient activities       136.0                 31.438
# ...                      ...         ...                    ...
# 358000              standing        93.0                 34.000
# 358001               ironing        90.0                 34.000
# 358003               cycling       104.0                 28.875
# 358005  transient activities        93.0                 34.438
# 358006               walking       110.0                 34.812
#
#         hand acceleration X ±16g  hand acceleration Y ±16g  \
# 0                         -7.333                     5.259
# 1                          1.850                     9.751
# 3                         -7.913                     4.096
# 5                         -5.420                     8.450
# 6                        -11.887                     3.339
# ...                          ...                       ...
# 358000                    -9.212                     2.909
# 358001                   -10.149                    -7.392
# 358003                    -6.589                     0.243
# 358005                    -9.832                     3.023
# 358006                   -10.653                     5.240
#
#         hand acceleration Z ±16g  hand gyroscope X  hand gyroscope Y  \
# 0                          3.184            -0.925             0.561
# 1                          0.189            -0.029            -0.147
# 3                          4.103            -0.007             0.015
# 5                          1.047            -0.329            -0.021
# 6                          5.124            -1.048            -0.779
# ...                          ...               ...               ...
# 358000                     1.740            -0.003            -0.043
# 358001                     7.341            -1.898            -0.073
# 358003                     7.138            -0.172             0.053
# 358005                     1.268             1.157            -0.354
# 358006                     6.560            -1.538             0.764
#
#         hand gyroscope Z  hand magnetometer X  ...  ankle acceleration X ±16g  \
# 0                  1.067               30.603  ...                      9.906
# 1                  0.024              -10.642  ...                      9.612
# 3                 -0.026               -2.096  ...                      9.115
# 5                  0.013               13.660  ...                      9.757
# 6                  1.312               36.271  ...                      6.811
# ...                  ...                  ...  ...                        ...
# 358000            -0.088               29.827  ...                      9.735
# 358001             0.823               12.710  ...                     10.177
# 358003            -0.027               51.066  ...                      9.445
# 358005            -0.948               35.211  ...                      9.792
# 358006            -3.022               48.058  ...                     13.769
#
#         ankle acceleration Y ±16g  ankle acceleration Z ±16g  \
# 0                           1.313                     -1.196
# 1                          -1.908                     -1.719
# 3                           0.999                     -3.942
# 5                           0.146                     -2.271
# 6                           5.665                     -1.641
# ...                           ...                        ...
# 358000                     -1.228                     -1.452
# 358001                     -0.087                     -1.918
# 358003                      2.297                     -0.474
# 358005                     -0.310                     -2.268
# 358006                     -5.739                    -10.027
#
#         ankle gyroscope X  ankle gyroscope Y  ankle gyroscope Z  \
# 0                  -0.002              0.686             -0.650
# 1                   0.008             -0.010              0.019
# 3                  -0.003             -0.053             -0.013
# 5                   0.039             -0.032              0.012
# 6                   1.111             -1.387             -2.204
# ...                   ...                ...                ...
# 358000             -0.007              0.035             -0.006
# 358001              0.083             -0.047              0.012
# 358003              0.005              0.045              0.006
# 358005             -0.051              0.092             -0.111
# 358006              1.934             -0.851             -4.128
#
#         ankle magnetometer X  ankle magnetometer Y  ankle magnetometer Z  \
# 0                    -70.820                 7.961                25.829
# 1                    -54.017                12.794                 5.848
# 3                    -85.338                38.258                16.031
# 5                     -0.257                -6.031                10.917
# 6                    -23.470                29.357                15.182
# ...                      ...                   ...                   ...
# 358000               -19.741                 0.780                38.984
# 358001               -35.478                10.754                42.686
# 358003               -31.580               -19.911                13.376
# 358005               -46.006                18.509                -5.544
# 358006               -15.547               -34.090                16.853
#
#         PeopleId
# 0              4
# 1              2
# 3              1
# 5              7
# 6              3
# ...          ...
# 358000         2
# 358001         6
# 358003         4
# 358005         2
# 358006         5
#
# [277713 rows x 33 columns]

# %%
# After removing outliers and storing the cleaned DataFrame in 'df_cleaned'
# Reset the index of the DataFrame
df_cleaned.reset_index(drop=True, inplace=True)

# %%
df_cleaned
# Out:
#                   activityID  heart_rate  hand temperature (°C)  \
# 0          descending stairs       116.0                 32.688
# 1       transient activities       117.0                 30.688
# 2                    sitting        93.0                 32.625
# 3                   standing        71.0                 32.500
# 4       transient activities       136.0                 31.438
# ...                      ...         ...                    ...
# 277708              standing        93.0                 34.000
# 277709               ironing        90.0                 34.000
# 277710               cycling       104.0                 28.875
# 277711  transient activities        93.0                 34.438
# 277712               walking       110.0                 34.812
#
#         hand acceleration X ±16g  hand acceleration Y ±16g  \
# 0                         -7.333                     5.259
# 1                          1.850                     9.751
# 2                         -7.913                     4.096
# 3                         -5.420                     8.450
# 4                        -11.887                     3.339
# ...                          ...                       ...
# 277708                    -9.212                     2.909
# 277709                   -10.149                    -7.392
# 277710                    -6.589                     0.243
# 277711                    -9.832                     3.023
# 277712                   -10.653                     5.240
#
#         hand acceleration Z ±16g  hand gyroscope X  hand gyroscope Y  \
# 0                          3.184            -0.925             0.561
# 1                          0.189            -0.029            -0.147
# 2                          4.103            -0.007             0.015
# 3                          1.047            -0.329            -0.021
# 4                          5.124            -1.048            -0.779
# ...                          ...               ...               ...
# 277708                     1.740            -0.003            -0.043
# 277709                     7.341            -1.898            -0.073
# 277710                     7.138            -0.172             0.053
# 277711                     1.268             1.157            -0.354
# 277712                     6.560            -1.538             0.764
#
#         hand gyroscope Z  hand magnetometer X  ...  ankle acceleration X ±16g  \
# 0                  1.067               30.603  ...                      9.906
# 1                  0.024              -10.642  ...                      9.612
# 2                 -0.026               -2.096  ...                      9.115
# 3                  0.013               13.660  ...                      9.757
# 4                  1.312               36.271  ...                      6.811
# ...                  ...                  ...  ...                        ...
# 277708            -0.088               29.827  ...                      9.735
# 277709             0.823               12.710  ...                     10.177
# 277710            -0.027               51.066  ...                      9.445
# 277711            -0.948               35.211  ...                      9.792
# 277712            -3.022               48.058  ...                     13.769
#
#         ankle acceleration Y ±16g  ankle acceleration Z ±16g  \
# 0                           1.313                     -1.196
# 1                          -1.908                     -1.719
# 2                           0.999                     -3.942
# 3                           0.146                     -2.271
# 4                           5.665                     -1.641
# ...                           ...                        ...
# 277708                     -1.228                     -1.452
# 277709                     -0.087                     -1.918
# 277710                      2.297                     -0.474
# 277711                     -0.310                     -2.268
# 277712                     -5.739                    -10.027
#
#         ankle gyroscope X  ankle gyroscope Y  ankle gyroscope Z  \
# 0                  -0.002              0.686             -0.650
# 1                   0.008             -0.010              0.019
# 2                  -0.003             -0.053             -0.013
# 3                   0.039             -0.032              0.012
# 4                   1.111             -1.387             -2.204
# ...                   ...                ...                ...
# 277708             -0.007              0.035             -0.006
# 277709              0.083             -0.047              0.012
# 277710              0.005              0.045              0.006
# 277711             -0.051              0.092             -0.111
# 277712              1.934             -0.851             -4.128
#
#         ankle magnetometer X  ankle magnetometer Y  ankle magnetometer Z  \
# 0                    -70.820                 7.961                25.829
# 1                    -54.017                12.794                 5.848
# 2                    -85.338                38.258                16.031
# 3                     -0.257                -6.031                10.917
# 4                    -23.470                29.357                15.182
# ...                      ...                   ...                   ...
# 277708               -19.741                 0.780                38.984
# 277709               -35.478                10.754                42.686
# 277710               -31.580               -19.911                13.376
# 277711               -46.006                18.509                -5.544
# 277712               -15.547               -34.090                16.853
#
#         PeopleId
# 0              4
# 1              2
# 2              1
# 3              7
# 4              3
# ...          ...
# 277708         2
# 277709         6
# 277710         4
# 277711         2
# 277712         5
#
# [277713 rows x 33 columns]

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_cleaned['activityID'] = le.fit_transform(df_cleaned['activityID'])

# %%
df_cleaned
# Out:
#         activityID  heart_rate  hand temperature (°C)  \
# 0                3       116.0                 32.688
# 1               10       117.0                 30.688
# 2                8        93.0                 32.625
# 3                9        71.0                 32.500
# 4               10       136.0                 31.438
# ...            ...         ...                    ...
# 277708           9        93.0                 34.000
# 277709           4        90.0                 34.000
# 277710           2       104.0                 28.875
# 277711          10        93.0                 34.438
# 277712          12       110.0                 34.812
#
#         hand acceleration X ±16g  hand acceleration Y ±16g  \
# 0                         -7.333                     5.259
# 1                          1.850                     9.751
# 2                         -7.913                     4.096
# 3                         -5.420                     8.450
# 4                        -11.887                     3.339
# ...                          ...                       ...
# 277708                    -9.212                     2.909
# 277709                   -10.149                    -7.392
# 277710                    -6.589                     0.243
# 277711                    -9.832                     3.023
# 277712                   -10.653                     5.240
#
#         hand acceleration Z ±16g  hand gyroscope X  hand gyroscope Y  \
# 0                          3.184            -0.925             0.561
# 1                          0.189            -0.029            -0.147
# 2                          4.103            -0.007             0.015
# 3                          1.047            -0.329            -0.021
# 4                          5.124            -1.048            -0.779
# ...                          ...               ...               ...
# 277708                     1.740            -0.003            -0.043
# 277709                     7.341            -1.898            -0.073
# 277710                     7.138            -0.172             0.053
# 277711                     1.268             1.157            -0.354
# 277712                     6.560            -1.538             0.764
#
#         hand gyroscope Z  hand magnetometer X  ...  ankle acceleration X ±16g  \
# 0                  1.067               30.603  ...                      9.906
# 1                  0.024              -10.642  ...                      9.612
# 2                 -0.026               -2.096  ...                      9.115
# 3                  0.013               13.660  ...                      9.757
# 4                  1.312               36.271  ...                      6.811
# ...                  ...                  ...  ...                        ...
# 277708            -0.088               29.827  ...                      9.735
# 277709             0.823               12.710  ...                     10.177
# 277710            -0.027               51.066  ...                      9.445
# 277711            -0.948               35.211  ...                      9.792
# 277712            -3.022               48.058  ...                     13.769
#
#         ankle acceleration Y ±16g  ankle acceleration Z ±16g  \
# 0                           1.313                     -1.196
# 1                          -1.908                     -1.719
# 2                           0.999                     -3.942
# 3                           0.146                     -2.271
# 4                           5.665                     -1.641
# ...                           ...                        ...
# 277708                     -1.228                     -1.452
# 277709                     -0.087                     -1.918
# 277710                      2.297                     -0.474
# 277711                     -0.310                     -2.268
# 277712                     -5.739                    -10.027
#
#         ankle gyroscope X  ankle gyroscope Y  ankle gyroscope Z  \
# 0                  -0.002              0.686             -0.650
# 1                   0.008             -0.010              0.019
# 2                  -0.003             -0.053             -0.013
# 3                   0.039             -0.032              0.012
# 4                   1.111             -1.387             -2.204
# ...                   ...                ...                ...
# 277708             -0.007              0.035             -0.006
# 277709              0.083             -0.047              0.012
# 277710              0.005              0.045              0.006
# 277711             -0.051              0.092             -0.111
# 277712              1.934             -0.851             -4.128
#
#         ankle magnetometer X  ankle magnetometer Y  ankle magnetometer Z  \
# 0                    -70.820                 7.961                25.829
# 1                    -54.017                12.794                 5.848
# 2                    -85.338                38.258                16.031
# 3                     -0.257                -6.031                10.917
# 4                    -23.470                29.357                15.182
# ...                      ...                   ...                   ...
# 277708               -19.741                 0.780                38.984
# 277709               -35.478                10.754                42.686
# 277710               -31.580               -19.911                13.376
# 277711               -46.006                18.509                -5.544
# 277712               -15.547               -34.090                16.853
#
#         PeopleId
# 0              4
# 1              2
# 2              1
# 3              7
# 4              3
# ...          ...
# 277708         2
# 277709         6
# 277710         4
# 277711         2
# 277712         5
#
# [277713 rows x 33 columns]

# %% [markdown]
# # Min Max Scaling

# %%
x = df_cleaned.drop('activityID',axis=1)

# %%
y = df_cleaned['activityID']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Create the MinMaxScaler object
scaler = MinMaxScaler()

# %%
# Fit and transform the data to perform Min-Max scaling
x_scaled = scaler.fit_transform(x)

# %%
x_scaled=pd.DataFrame(x_scaled,columns=x.columns)

# %%
x_scaled.head()
# Out:
#    heart_rate  hand temperature (°C)  hand acceleration X ±16g  \
# 0       0.453                  0.651                     0.434
# 1       0.461                  0.403                     0.690
# 2       0.276                  0.643                     0.418
# 3       0.107                  0.628                     0.488
# 4       0.606                  0.496                     0.308
#
#    hand acceleration Y ±16g  hand acceleration Z ±16g  hand gyroscope X  \
# 0                     0.545                     0.500             0.382
# 1                     0.666                     0.369             0.497
# 2                     0.514                     0.540             0.500
# 3                     0.631                     0.407             0.458
# 4                     0.494                     0.585             0.366
#
#    hand gyroscope Y  hand gyroscope Z  hand magnetometer X  \
# 0             0.600             0.623                0.566
# 1             0.467             0.503                0.279
# 2             0.497             0.498                0.338
# 3             0.490             0.502                0.448
# 4             0.348             0.651                0.605
#
#    hand magnetometer Y  ...  ankle acceleration X ±16g  \
# 0                0.407  ...                      0.510
# 1                0.316  ...                      0.502
# 2                0.261  ...                      0.487
# 3                0.377  ...                      0.506
# 4                0.517  ...                      0.419
#
#    ankle acceleration Y ±16g  ankle acceleration Z ±16g  ankle gyroscope X  \
# 0                      0.535                      0.559              0.499
# 1                      0.456                      0.535              0.500
# 2                      0.527                      0.430              0.499
# 3                      0.507                      0.509              0.505
# 4                      0.642                      0.538              0.672
#
#    ankle gyroscope Y  ankle gyroscope Z  ankle magnetometer X  \
# 0              0.702              0.441                 0.164
# 1              0.507              0.501                 0.312
# 2              0.495              0.498                 0.036
# 3              0.501              0.501                 0.787
# 4              0.122              0.300                 0.582
#
#    ankle magnetometer Y  ankle magnetometer Z  PeopleId
# 0                 0.549                 0.574     0.429
# 1                 0.586                 0.410     0.143
# 2                 0.783                 0.494     0.000
# 3                 0.441                 0.452     0.857
# 4                 0.714                 0.487     0.286
#
# [5 rows x 32 columns]

# %%
x_scaled.columns
# Out:
# Index(['heart_rate', 'hand temperature (°C)', 'hand acceleration X ±16g',
#        'hand acceleration Y ±16g', 'hand acceleration Z ±16g',
#        'hand gyroscope X', 'hand gyroscope Y', 'hand gyroscope Z',
#        'hand magnetometer X', 'hand magnetometer Y', 'hand magnetometer Z',
#        'chest temperature (°C)', 'chest acceleration X ±16g',
#        'chest acceleration Y ±16g', 'chest acceleration Z ±16g',
#        'chest gyroscope X', 'chest gyroscope Y', 'chest gyroscope Z',
#        'chest magnetometer X', 'chest magnetometer Y', 'chest magnetometer Z',
#        'ankle temperature (°C)', 'ankle acceleration X ±16g',
#        'ankle acceleration Y ±16g', 'ankle acceleration Z ±16g',
#        'ankle gyroscope X', 'ankle gyroscope Y', 'ankle gyroscope Z',
#        'ankle magnetometer X', 'ankle magnetometer Y', 'ankle magnetometer Z',
#        'PeopleId'],
#       dtype='object')

# %% [markdown]
# **Principal Component Analysis**

# %%
# First import the library
from sklearn.decomposition import PCA

# %%
# Fit and transform the data to do PCA
pca=PCA(n_components=0.97)
pca.fit(x_scaled)
# Out:
# PCA(n_components=0.97)

# %%
x_pca=pca.transform(x_scaled)

# %%
x_pca.shape
# Out:
# (277713, 27)

# %%
x_pca=pd.DataFrame(x_pca)

# %%
x_pca.columns
# Out:
# RangeIndex(start=0, stop=27, step=1)

# %%
original_column_names = ['heart_rate', 'hand temperature (°C)', 'hand acceleration X ±16g',
       'hand acceleration Y ±16g', 'hand acceleration Z ±16g',
       'hand gyroscope X', 'hand gyroscope Y', 'hand gyroscope Z',
       'hand magnetometer X', 'hand magnetometer Y', 'hand magnetometer Z',
       'chest temperature (°C)', 'chest acceleration X ±16g',
       'chest acceleration Y ±16g', 'chest acceleration Z ±16g',
       'chest gyroscope X', 'chest gyroscope Y', 'chest gyroscope Z',
       'chest magnetometer X', 'chest magnetometer Y', 'chest magnetometer Z',
       'ankle temperature (°C)', 'ankle acceleration X ±16g',
       'ankle acceleration Y ±16g', 'ankle acceleration Z ±16g',
       'ankle gyroscope X', 'ankle gyroscope Y', 'ankle gyroscope Z',
       'ankle magnetometer X', 'ankle magnetometer Y', 'ankle magnetometer Z',
       'PeopleId']

# Mapping indices to column names
pca_column_names = [original_column_names[i] for i in range(len(x_pca.columns))]

# Display the PCA column names
print(pca_column_names)
# Out:
# ['heart_rate', 'hand temperature (°C)', 'hand acceleration X ±16g', 'hand acceleration Y ±16g', 'hand acceleration Z ±16g', 'hand gyroscope X', 'hand gyroscope Y', 'hand gyroscope Z', 'hand magnetometer X', 'hand magnetometer Y', 'hand magnetometer Z', 'chest temperature (°C)', 'chest acceleration X ±16g', 'chest acceleration Y ±16g', 'chest acceleration Z ±16g', 'chest gyroscope X', 'chest gyroscope Y', 'chest gyroscope Z', 'chest magnetometer X', 'chest magnetometer Y', 'chest magnetometer Z', 'ankle temperature (°C)', 'ankle acceleration X ±16g', 'ankle acceleration Y ±16g', 'ankle acceleration Z ±16g', 'ankle gyroscope X', 'ankle gyroscope Y']

# %% [markdown]
# *Train test split*

# %%
from sklearn.model_selection import train_test_split

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_pca, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Modelling using different Algorithms

# %% [markdown]
# # Logistic Regression model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
# Train the Logistic Regression model
lr_model = LogisticRegression(random_state=42)
lr_model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
# Make predictions on the test set
lr_y_pred = lr_model.predict(x_test)

# %%
# Evaluate the model
print("Logistic Regression:")
print("Accuracy:", accuracy_score(y_test, lr_y_pred))
print(classification_report(y_test, lr_y_pred))
# Out:
# Logistic Regression:
# Accuracy: 0.7215490700898403
#               precision    recall  f1-score   support
#
#            0       0.65      0.32      0.43      3158
#            1       0.64      0.34      0.45      2063
#            2       0.87      0.91      0.89      3697
#            3       0.54      0.12      0.20      1486
#            4       0.81      0.86      0.84      5529
#            5       0.99      0.95      0.97      4017
#            6       0.80      0.45      0.57       314
#            7       0.89      0.54      0.67       305
#            8       0.83      0.86      0.84      4592
#            9       0.74      0.74      0.74      4363
#           10       0.62      0.78      0.69     18553
#           11       0.76      0.65      0.70      3482
#           12       0.65      0.49      0.56      3984
#
#     accuracy                           0.72     55543
#    macro avg       0.75      0.62      0.66     55543
# weighted avg       0.72      0.72      0.71     55543

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Train the Decision Tree model
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Make predictions on the test set
dt_y_pred = dt_model.predict(x_test)

# %%
# Evaluate the model
print("Decision Tree:")
print("Accuracy:", accuracy_score(y_test, dt_y_pred))
print(classification_report(y_test, dt_y_pred))
# Out:
# Decision Tree:
# Accuracy: 0.875339826800857
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83      3158
#            1       0.63      0.62      0.63      2063
#            2       0.93      0.93      0.93      3697
#            3       0.54      0.52      0.53      1486
#            4       0.93      0.94      0.93      5529
#            5       0.99      0.99      0.99      4017
#            6       0.82      0.74      0.78       314
#            7       0.73      0.75      0.74       305
#            8       0.98      0.97      0.98      4592
#            9       0.95      0.96      0.95      4363
#           10       0.87      0.88      0.87     18553
#           11       0.81      0.79      0.80      3482
#           12       0.82      0.81      0.82      3984
#
#     accuracy                           0.88     55543
#    macro avg       0.83      0.82      0.83     55543
# weighted avg       0.87      0.88      0.87     55543

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Train the Random Forest model
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Make predictions on the test set
rf_y_pred = rf_model.predict(x_test)

# %%
# Evaluate the model
print("Random Forest:")
print("Accuracy:", accuracy_score(y_test, rf_y_pred))
print(classification_report(y_test, rf_y_pred))
# Out:
# Random Forest:
# Accuracy: 0.9566101939038223
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97      3158
#            1       0.95      0.78      0.86      2063
#            2       0.99      0.98      0.99      3697
#            3       0.97      0.59      0.73      1486
#            4       0.98      0.99      0.98      5529
#            5       1.00      0.99      1.00      4017
#            6       0.98      0.83      0.90       314
#            7       0.99      0.87      0.92       305
#            8       1.00      0.99      0.99      4592
#            9       0.99      0.99      0.99      4363
#           10       0.91      0.98      0.94     18553
#           11       0.98      0.92      0.95      3482
#           12       0.97      0.94      0.95      3984
#
#     accuracy                           0.96     55543
#    macro avg       0.98      0.91      0.94     55543
# weighted avg       0.96      0.96      0.96     55543

# %% [markdown]
# **KNN Model**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# create an empty list.
metric_k=[]
neighbors=np.arange(3,15)

# %%
# Train the KNN model
for k in neighbors:
  knn_model=KNeighborsClassifier(n_neighbors=k,metric='euclidean')
  knn_model.fit(x_train,y_train)
  # Make predictions on the test set
  knn_y_pred=knn_model.predict(x_test)
  acc=accuracy_score(y_test,knn_y_pred)
  metric_k.append(acc)

# %%
# Lets plot a graph to find highest accuracy score of given k
plt.plot(neighbors,metric_k,'o-')
plt.xlabel('k')
plt.ylabel('Accuracy')
plt.grid()

# %%
# Lets create knn model for 3 neighbors
knn_model=KNeighborsClassifier(n_neighbors=3,metric='euclidean')
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=3)

# %%
# Make predictions on the test set
knn_y_pred=knn_model.predict(x_test)

# %%
# Evaluate the model
print("KNN Model:")
print("Accuracy:", accuracy_score(y_test, knn_y_pred))
print(classification_report(y_test, knn_y_pred))
# Out:
# KNN Model:
# Accuracy: 0.970077237455665
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      3158
#            1       0.91      0.90      0.91      2063
#            2       0.99      1.00      0.99      3697
#            3       0.90      0.84      0.87      1486
#            4       0.98      0.99      0.99      5529
#            5       1.00      0.99      0.99      4017
#            6       0.94      0.92      0.93       314
#            7       0.98      0.93      0.95       305
#            8       1.00      0.99      1.00      4592
#            9       0.99      0.99      0.99      4363
#           10       0.97      0.96      0.96     18553
#           11       0.98      0.97      0.97      3482
#           12       0.92      0.98      0.95      3984
#
#     accuracy                           0.97     55543
#    macro avg       0.96      0.96      0.96     55543
# weighted avg       0.97      0.97      0.97     55543

# %% [markdown]
# **SVM Model**

# %%
from sklearn.svm import SVC
svm_model=SVC(kernel='linear')
svm_model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
# Make predictions on the test set
svm_y_pred=svm_model.predict(x_test)

# %%
# Evaluate the model
print("SVM Model:")
print("Accuracy:", accuracy_score(y_test, svm_y_pred))
print(classification_report(y_test, svm_y_pred))
# Out:
# SVM Model:
# Accuracy: 0.7295608807590516
#               precision    recall  f1-score   support
#
#            0       0.75      0.15      0.25      3158
#            1       0.57      0.07      0.12      2063
#            2       0.89      0.93      0.91      3697
#            3       0.65      0.02      0.04      1486
#            4       0.84      0.89      0.87      5529
#            5       0.98      0.95      0.97      4017
#            6       0.97      0.37      0.54       314
#            7       0.94      0.52      0.67       305
#            8       0.87      0.88      0.88      4592
#            9       0.79      0.81      0.80      4363
#           10       0.59      0.85      0.70     18553
#           11       0.85      0.62      0.72      3482
#           12       0.75      0.48      0.58      3984
#
#     accuracy                           0.73     55543
#    macro avg       0.80      0.58      0.62     55543
# weighted avg       0.75      0.73      0.70     55543

# %% [markdown]
# When comparing 5 models, accuracy is higher for KNN-model.

# %% [markdown]
# **Hyperparameter tuning for KNN model**

# %% [markdown]
# *Randomsearch CV*

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_dist = {
    'n_neighbors': range(3, 15),
    'weights': ['uniform', 'distance'],
    'p': [1, 2]
}

# %%
# perform randomized search cv
random_search = RandomizedSearchCV(
    knn_model,
    param_distributions=param_dist,
    n_iter=10,  # Number of parameter settings to sample
    cv=2,       # Cross-validation folds
    random_state=42
)

random_search.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=2,
#                    estimator=KNeighborsClassifier(metric='euclidean',
#                                                   n_neighbors=3),
#                    param_distributions={'n_neighbors': range(3, 15),
#                                         'p': [1, 2],
#                                         'weights': ['uniform', 'distance']},
#                    random_state=42)

# %%
# Print best parameters
print("Best parameters:", random_search.best_params_)
# Out:
# Best parameters: {'weights': 'uniform', 'p': 1, 'n_neighbors': 4}

# %%
# Make predictions
best_knn = random_search.best_estimator_

predictions = best_knn.predict(x_test)

# %%
# Evaluate the model
print("Randomsearch Model:")
print("Accuracy:", accuracy_score(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Randomsearch Model:
# Accuracy: 0.9659543056730822
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      3158
#            1       0.88      0.92      0.90      2063
#            2       0.99      1.00      0.99      3697
#            3       0.87      0.85      0.86      1486
#            4       0.97      1.00      0.98      5529
#            5       1.00      0.99      0.99      4017
#            6       0.93      0.94      0.93       314
#            7       0.95      0.94      0.95       305
#            8       0.99      0.99      0.99      4592
#            9       0.98      0.99      0.99      4363
#           10       0.97      0.95      0.96     18553
#           11       0.98      0.95      0.96      3482
#           12       0.93      0.97      0.95      3984
#
#     accuracy                           0.97     55543
#    macro avg       0.95      0.96      0.96     55543
# weighted avg       0.97      0.97      0.97     55543

# %% [markdown]
# Accuracy is similar to the original model.

# %% [markdown]
# **Saving the model to disk**

# %%
import pickle

# %%
pickle.dump(knn_model,open('knn_model.pkl','wb'))
